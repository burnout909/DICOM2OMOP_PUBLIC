# %% [markdown]
# # DICOM Standard harvesting of Part 3
# ## Extract relationships between Tags and Value Sets
#
# [Click to access an online XML viewer](https://jsonformatter.org/xml-viewer)
#
# Links to the XML Objects
# - [DICOM Part 3](https://dicom.nema.org/medical/dicom/current/source/docbook/part03/part03.xml)
# - [DICOM Part 6](https://dicom.nema.org/medical/dicom/current/source/docbook/part06/part06.xml)
# - [DICOM Part 16](https://dicom.nema.org/medical/dicom/current/source/docbook/part16/part16.xml)
#
# This notebook demonstrates how to parse out DICOM Part 3.
# 1. Extract one IOD module table: A.36 Enhanced MR and its Reference tables
# 2. Extract all IOD module tables and their Reference tables

# %% [markdown]
# ## 1.a Extract one IOD Module Table: A.36 Enhanced MR

# %%
import requests
from bs4 import BeautifulSoup

# Fetch XML content from the URL
url = 'https://dicom.nema.org/medical/dicom/current/source/docbook/part03/part03.xml' #Part3 Standard XML
response = requests.get(url) #response 객체에서 데이터 저장
xml_content = response.content #서버로부터 받은 응답 원시 바이트 데이터로 변환

# Parse the XML content
soup = BeautifulSoup(xml_content, 'xml') #XML 데이터를 계층 구조로 분석

# %%
import requests
import pandas as pd

#Find the table with label 'A.36-1'
table = soup.find('table', {'label' : 'A.36-1'})
table
# Out:
# <table frame="box" label="A.36-1" rules="all" xml:id="table_A.36-1">
# <caption>Enhanced MR Image IOD Modules</caption>
# <thead>
# <tr valign="top">
# <th align="center" colspan="1" rowspan="1">
# <para xml:id="para_2efea782-6f1b-47ce-8516-5b06a65a0fc5">IE</para>
# </th>
# <th align="center" colspan="1" rowspan="1">
# <para xml:id="para_029f7031-5b56-436e-968d-23d9ba46a81e">Module</para>
# </th>
# <th align="center" colspan="1" rowspan="1">
# <para xml:id="para_630bd1aa-5c0e-4ebc-b007-287684f6cd4b">Reference</para>
# </th>
# <th align="center" colspan="1" rowspan="1">
# <para xml:id="para_4d8c0d47-27c1-4318-9b9e-dd59ef36c1e4">Usage</para>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="2">
# <para xml:id="para_d2335fce-97b7-4175-9953-e2c89b17b578">Patient</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_e2c47885-4138-43c3-8097-4f6e7c77d192">Patient</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_cb68633d-303b-4b1f-a3b2-830475544b36">
# <xref linkend="sect_C.7.1.1" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_a7f7ff66-d28a-4b45-84cf-6d95d2f002ed">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_5c3e58f2-3df7-401a-a373-1680fddaebea">Clinical Trial Subject</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_2f997bad-b640-4dc1-bef7-6f2c64b801f0">
# <xref linkend="sect_C.7.1.3" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_2be81b10-e334-4e0a-8b50-f1258e4f6fea">U</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="3">
# <para xml:id="para_962c4a65-6984-4b75-b6da-c4da007f08ae">Study</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_8416f16c-4fde-4eb3-8fd1-00601b473cab">General Study</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_a7eb8b47-11e5-4a49-9333-f84a5f63ad64">
# <xref linkend="sect_C.7.2.1" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_3309e2fd-be5a-43b7-8afc-26bb57fc6270">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_79978e59-3fba-4e54-a5d4-64e49283266a">Patient Study</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_b62702a7-a7de-47f9-98f8-0e6fa7c686aa">
# <xref linkend="sect_C.7.2.2" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_802675b0-e5fc-4815-a8b4-f508ec0e87d4">U</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_a1207ae3-d69e-4a8c-80f6-854fd80242fe">Clinical Trial Study</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_65226c70-1dc2-4449-bf68-538347bc264b">
# <xref linkend="sect_C.7.2.3" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_19441e97-54a1-4c57-a7b5-30880d5bce4a">U</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="3">
# <para xml:id="para_888dd421-32ff-478d-8c00-3ff48951d66b">Series</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_1b1c906f-2fd2-4c8b-82b3-3953c18c2b3c">General Series</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_1f2251e2-d6a2-4a2f-921a-0496fc0e1c4a">
# <xref linkend="sect_C.7.3.1" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_fd158dba-b808-4848-889d-9f4c0f839c06">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_d7f6f817-55df-4499-ba00-4f5d3a98a331">Clinical Trial Series</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_e796dcd0-bfce-4dfe-8157-6d7be00367ba">
# <xref linkend="sect_C.7.3.2" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_235a5384-3212-49d3-9a6e-03bc94e6e9df">U</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_2e63a38d-3131-4851-a776-da7e66c899e9">MR Series</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_7762cb07-c9c5-4fab-af1c-20c82200a9ca">
# <xref linkend="sect_C.8.13.6" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_5bc82fad-8302-4fe6-b9be-e678f4f5a775">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="2">
# <para xml:id="para_26b8702d-ef2c-4dd9-93e1-f12b1e0883b4">Frame of Reference</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_9b82a723-01d9-4a27-9142-e6e73e6f04cb">Frame of Reference</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_2a18ea22-007d-4af8-9a35-ac3c05d114e3">
# <xref linkend="sect_C.7.4.1" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_2d2068f8-7711-4d7c-b055-0d9dc4de0e90">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_75d6b172-d4a8-4c9e-8153-59f903a6e2c3">Synchronization</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_b23b3738-100c-49e4-be28-c15f01d5181e">
# <xref linkend="sect_C.7.4.2" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_e8221597-1ff3-4fe8-966f-49a9a429a876">C - Required if time synchronization was applied.</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="2">
# <para xml:id="para_c71a5ef5-066c-4c66-abfe-ecfe470fb571">Equipment</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_e4c2e62b-7eb1-4cb1-a637-ab9e08ffdf88">General Equipment</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_9a34df4f-efd3-4d16-9777-65f6648d25c1">
# <xref linkend="sect_C.7.5.1" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_fe9f9cc5-728d-474f-a4a7-349295ead1f5">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_c8257007-6b45-42cd-a01f-e537dbcbc650">Enhanced General Equipment</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_7f90fc47-6832-4017-9ff4-3a20b06aa5c9">
# <xref linkend="sect_C.7.5.2" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_a29e7e9a-5765-4957-96cc-05e08842cd9f">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="18">
# <para xml:id="para_6e98b225-e7cd-42cc-b80d-e73a8b2cf622">Image</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_69d9885d-ae27-4fbc-9ad1-887410e2f1ab">Image Pixel</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_eb10323b-4f76-4af8-b445-9922cdef9d16">
# <xref linkend="sect_C.7.6.3" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_e714bec5-d9fa-4e59-a251-14d54e7f8c84">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para>Enhanced Patient Orientation</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para>
# <xref linkend="sect_C.7.6.30" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para>U</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_621c0d4b-5785-4564-9637-500aee7b2f40">Enhanced Contrast/Bolus</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_9d761d86-176a-48ed-9a31-fbc8fee2dd0d">
# <xref linkend="sect_C.7.6.4b" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_be35a623-3cd1-45dc-b255-4aaf773aa17f">C - Required if contrast media were applied.</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_1d24d903-849d-466e-b476-47f6c5e8ebcd">Multi-frame Functional Groups</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_e333b526-1b32-4cce-93e2-9f6404089924">
# <xref linkend="sect_C.7.6.16" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_28439a53-b985-4b7c-8c5a-78248a96d8cf">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_3485b05d-7edc-4f06-bde0-7cbfb89ba90e">Multi-frame Dimension</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_6972bf17-61cf-4957-9ff4-ee4cf534a1f2">
# <xref linkend="sect_C.7.6.17" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_9961755d-3b25-4083-bade-5bc0358ee6fc">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_534a3e08-89a9-494d-86ab-6c6da71829f2">Cardiac Synchronization</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_b1eef313-4c42-48e6-b0f3-0e4afdfd12ab">
# <xref linkend="sect_C.7.6.18.1" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_9fb610af-9d9b-432c-9f87-9317233e341d">C - Required if cardiac synchronization was applied.</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_3edb12ff-370e-4bf9-8cb2-3b474952917b">Respiratory Synchronization</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_3293209c-c0f1-47f8-b0d4-62e947b9dafe">
# <xref linkend="sect_C.7.6.18.2" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_c321ce3a-0860-46f5-86d6-8ac3b3765828">C - Required if respiratory synchronization was applied.</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_06132d1c-c70b-47e1-94de-b11f773cf3c6">Bulk Motion Synchronization</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_7d40e011-2713-4fa0-b3c3-4bdf21ed9bb3">
# <xref linkend="sect_C.7.6.18.3" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_a10800b0-55e7-4076-96be-ba94fecb2622">C - Required if bulk motion synchronization was applied.</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_28e5d84d-c87d-4414-9c3f-e1f5d5ae17ee">Supplemental Palette Color Lookup Table</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_aea3ab90-393d-476a-b6fb-7b5bd4898f69">
# <xref linkend="sect_C.7.6.19" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_bc3c9290-f931-4055-9432-ccd9861fd730">C - Required if Pixel Presentation (0008,9205) in the <xref linkend="sect_C.8.13.1" xrefstyle="select: title"/> equals COLOR or MIXED.</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_d7a6d504-146e-42b4-938e-70f5399b5f33">Acquisition Context</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_c03b1ec3-736d-407f-9daf-26893c05fd65">
# <xref linkend="sect_C.7.6.14" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_deb43af4-6afc-45e3-81f9-a104afb574c8">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_d7463b30-23df-481c-86cc-6750aec6a651">Device</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_12fbcbf2-bda6-4392-97cc-31791edd0171">
# <xref linkend="sect_C.7.6.12" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_43936e80-1506-4a70-90d1-1c8c6aff6b5e">U</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_4f5d7864-4595-4acb-982f-24ba49f23762">Specimen</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_f6c32a50-83b8-414f-8fb1-7c177a1b1f1d">
# <xref linkend="sect_C.7.6.22" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_08556fa7-ac91-4ede-a386-fdebd7e43779">U</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_05b2f497-10a1-4758-a074-c85ff0c824a0">Enhanced MR Image</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_b5d6f71a-a221-4d61-825d-ae6ba0cb2214">
# <xref linkend="sect_C.8.13.1" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_f6154027-2c4b-4ce0-a4bd-a81c8f289f31">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_7e65b6db-3657-430c-b22f-665f24e67f9f">MR Pulse Sequence</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_72882a0c-a3f4-475c-bbd9-b09fca5a3d5d">
# <xref linkend="sect_C.8.13.4" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_f22930de-2b3f-4ceb-9aca-1734e5018e6d">C - Required if Image Type (0008,0008) Value 1 is ORIGINAL or MIXED. May be present otherwise.</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_7ac1e796-b869-401a-baa2-e9eb177de35f">ICC Profile</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_595dba09-78f5-40ce-9a29-31e7c11c2ca2">
# <xref linkend="sect_C.11.15" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_2befcfff-fa82-4911-8599-9ef122a168bc">U</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_25127c69-7484-4b7a-83d0-17d26dfffa75">SOP Common</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_a84e725b-f303-491e-a749-35af8f705189">
# <xref linkend="sect_C.12.1" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_93d76444-dff5-40b7-a5cd-f44840f99680">M</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_e0d09e49-961f-4650-83db-69fcba6020a1">Common Instance Reference</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_ea9b6b52-260f-4d90-8efe-cb9578895620">
# <xref linkend="sect_C.12.2" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_82c9b6a7-6416-44e3-97c1-67887c5a8ae7">U</para>
# </td>
# </tr>
# <tr valign="top">
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_95ba0586-7d06-4f09-b071-a29ccae6ffab">Frame Extraction</para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_e472ae40-1502-4230-ba4d-05e342c94eec">
# <xref linkend="sect_C.12.3" xrefstyle="select: labelnumber"/>
# </para>
# </td>
# <td align="left" colspan="1" rowspan="1">
# <para xml:id="para_85a8e327-20e0-4f26-a51b-613fb5f18723">C - Required if the SOP Instance was created in response to a Frame-Level retrieve request</para>
# </td>
# </tr>
# </tbody>
# </table>

# %%
#Find the section containing the table and extract its title
section_title = soup.find('section', {'xml:id':table.parent['xml:id']}).find('title').text.strip()
section_title
# Out:
# 'Enhanced MR Image IOD Module Table'

# %%
#Extract the part of the title before "IOD"
iod_index = section_title.find(" IOD")
iod = section_title[:iod_index]
iod
# Out:
# 'Enhanced MR Image'

# %%
#Extract table headers
headers = [th.text.strip() for th in table.find_all('th')]
headers
# Out:
# ['IE', 'Module', 'Reference', 'Usage']

# %%
# Extract table rows
rows = []
current_ie = None
for tr in table.find_all('tr')[1:]:  # Skip the header row
    cells = tr.find_all(['td', 'th'])

    # Extract cell values
    cell_values = [cell.text.strip() for cell in cells]

    # Check if the cell values are complete (some cells may be missing due to rowspan)
    if len(cell_values) < len(headers):
        # Fill in the missing values based on the previous row
        for i in range(len(headers) - len(cell_values)):
            cell_values.insert(0, current_ie)

    # Store the IE value for the next iteration
    current_ie = cell_values[0]

    # Extract the reference value if available
    reference = None
    for cell in cells:
        xref = cell.find('xref', {'xrefstyle': 'select: labelnumber'})
        if xref:
            reference = xref['linkend']
            break

    # Insert the reference value into the correct position
    if reference:
        # Find the index of the cell containing the reference
        reference_index = next((idx for idx, val in enumerate(cell_values) if val == ''), None)
        if reference_index is not None:
            cell_values[reference_index] = reference

    # Insert the title of the table as the first element
    cell_values.insert(0, iod)

    rows.append(cell_values)

rows
# Out:
# [['Enhanced MR Image', 'Patient', 'Patient', 'sect_C.7.1.1', 'M'],
#  ['Enhanced MR Image',
#   'Patient',
#   'Clinical Trial Subject',
#   'sect_C.7.1.3',
#   'U'],
#  ['Enhanced MR Image', 'Study', 'General Study', 'sect_C.7.2.1', 'M'],
#  ['Enhanced MR Image', 'Study', 'Patient Study', 'sect_C.7.2.2', 'U'],
#  ['Enhanced MR Image', 'Study', 'Clinical Trial Study', 'sect_C.7.2.3', 'U'],
#  ['Enhanced MR Image', 'Series', 'General Series', 'sect_C.7.3.1', 'M'],
#  ['Enhanced MR Image', 'Series', 'Clinical Trial Series', 'sect_C.7.3.2', 'U'],
#  ['Enhanced MR Image', 'Series', 'MR Series', 'sect_C.8.13.6', 'M'],
#  ['Enhanced MR Image',
#   'Frame of Reference',
#   'Frame of Reference',
#   'sect_C.7.4.1',
#   'M'],
#  ['Enhanced MR Image',
#   'Frame of Reference',
#   'Synchronization',
#   'sect_C.7.4.2',
#   'C - Required if time synchronization was applied.'],
#  ['Enhanced MR Image', 'Equipment', 'General Equipment', 'sect_C.7.5.1', 'M'],
#  ['Enhanced MR Image',
#   'Equipment',
#   'Enhanced General Equipment',
#   'sect_C.7.5.2',
#   'M'],
#  ['Enhanced MR Image', 'Image', 'Image Pixel', 'sect_C.7.6.3', 'M'],
#  ['Enhanced MR Image',
#   'Image',
#   'Enhanced Patient Orientation',
#   'sect_C.7.6.30',
#   'U'],
#  ['Enhanced MR Image',
#   'Image',
#   'Enhanced Contrast/Bolus',
#   'sect_C.7.6.4b',
#   'C - Required if contrast media were applied.'],
#  ['Enhanced MR Image',
#   'Image',
#   'Multi-frame Functional Groups',
#   'sect_C.7.6.16',
#   'M'],
#  ['Enhanced MR Image', 'Image', 'Multi-frame Dimension', 'sect_C.7.6.17', 'M'],
#  ['Enhanced MR Image',
#   'Image',
#   'Cardiac Synchronization',
#   'sect_C.7.6.18.1',
#   'C - Required if cardiac synchronization was applied.'],
#  ['Enhanced MR Image',
#   'Image',
#   'Respiratory Synchronization',
#   'sect_C.7.6.18.2',
#   'C - Required if respiratory synchronization was applied.'],
#  ['Enhanced MR Image',
#   'Image',
#   'Bulk Motion Synchronization',
#   'sect_C.7.6.18.3',
#   'C - Required if bulk motion synchronization was applied.'],
#  ['Enhanced MR Image',
#   'Image',
#   'Supplemental Palette Color Lookup Table',
#   'sect_C.7.6.19',
#   'C - Required if Pixel Presentation (0008,9205) in the  equals COLOR or MIXED.'],
#  ['Enhanced MR Image', 'Image', 'Acquisition Context', 'sect_C.7.6.14', 'M'],
#  ['Enhanced MR Image', 'Image', 'Device', 'sect_C.7.6.12', 'U'],
#  ['Enhanced MR Image', 'Image', 'Specimen', 'sect_C.7.6.22', 'U'],
#  ['Enhanced MR Image', 'Image', 'Enhanced MR Image', 'sect_C.8.13.1', 'M'],
#  ['Enhanced MR Image',
#   'Image',
#   'MR Pulse Sequence',
#   'sect_C.8.13.4',
#   'C - Required if Image Type (0008,0008) Value 1 is ORIGINAL or MIXED. May be present otherwise.'],
#  ['Enhanced MR Image', 'Image', 'ICC Profile', 'sect_C.11.15', 'U'],
#  ['Enhanced MR Image', 'Image', 'SOP Common', 'sect_C.12.1', 'M'],
#  ['Enhanced MR Image',
#   'Image',
#   'Common Instance Reference',
#   'sect_C.12.2',
#   'U'],
#  ['Enhanced MR Image',
#   'Image',
#   'Frame Extraction',
#   'sect_C.12.3',
#   'C - Required if the SOP Instance was created in response to a Frame-Level retrieve request']]

# %%
# Create a DataFrame
df_iod = pd.DataFrame(rows, columns=['IOD'] + headers)
df_iod
# IOD: Information Object Definition -> DICOM 데이터의 전체적 구조 정의
# IE: Information Entity ex) Patient, Study, Series, Image
# Module: tag group
# Reference: 참조 위치, DICOM Standard 문서의 section
# Usage: see next block
# Out:
#                   IOD                  IE  \
# 0   Enhanced MR Image             Patient
# 1   Enhanced MR Image             Patient
# 2   Enhanced MR Image               Study
# 3   Enhanced MR Image               Study
# 4   Enhanced MR Image               Study
# 5   Enhanced MR Image              Series
# 6   Enhanced MR Image              Series
# 7   Enhanced MR Image              Series
# 8   Enhanced MR Image  Frame of Reference
# 9   Enhanced MR Image  Frame of Reference
# 10  Enhanced MR Image           Equipment
# 11  Enhanced MR Image           Equipment
# 12  Enhanced MR Image               Image
# 13  Enhanced MR Image               Image
# 14  Enhanced MR Image               Image
# 15  Enhanced MR Image               Image
# 16  Enhanced MR Image               Image
# 17  Enhanced MR Image               Image
# 18  Enhanced MR Image               Image
# 19  Enhanced MR Image               Image
# 20  Enhanced MR Image               Image
# 21  Enhanced MR Image               Image
# 22  Enhanced MR Image               Image
# 23  Enhanced MR Image               Image
# 24  Enhanced MR Image               Image
# 25  Enhanced MR Image               Image
# 26  Enhanced MR Image               Image
# 27  Enhanced MR Image               Image
# 28  Enhanced MR Image               Image
# 29  Enhanced MR Image               Image
#
#                                      Module        Reference  \
# 0                                   Patient     sect_C.7.1.1
# 1                    Clinical Trial Subject     sect_C.7.1.3
# 2                             General Study     sect_C.7.2.1
# 3                             Patient Study     sect_C.7.2.2
# 4                      Clinical Trial Study     sect_C.7.2.3
# 5                            General Series     sect_C.7.3.1
# 6                     Clinical Trial Series     sect_C.7.3.2
# 7                                 MR Series    sect_C.8.13.6
# 8                        Frame of Reference     sect_C.7.4.1
# 9                           Synchronization     sect_C.7.4.2
# 10                        General Equipment     sect_C.7.5.1
# 11               Enhanced General Equipment     sect_C.7.5.2
# 12                              Image Pixel     sect_C.7.6.3
# 13             Enhanced Patient Orientation    sect_C.7.6.30
# 14                  Enhanced Contrast/Bolus    sect_C.7.6.4b
# 15            Multi-frame Functional Groups    sect_C.7.6.16
# 16                    Multi-frame Dimension    sect_C.7.6.17
# 17                  Cardiac Synchronization  sect_C.7.6.18.1
# 18              Respiratory Synchronization  sect_C.7.6.18.2
# 19              Bulk Motion Synchronization  sect_C.7.6.18.3
# 20  Supplemental Palette Color Lookup Table    sect_C.7.6.19
# 21                      Acquisition Context    sect_C.7.6.14
# 22                                   Device    sect_C.7.6.12
# 23                                 Specimen    sect_C.7.6.22
# 24                        Enhanced MR Image    sect_C.8.13.1
# 25                        MR Pulse Sequence    sect_C.8.13.4
# 26                              ICC Profile     sect_C.11.15
# 27                               SOP Common      sect_C.12.1
# 28                Common Instance Reference      sect_C.12.2
# 29                         Frame Extraction      sect_C.12.3
#
#                                                 Usage
# 0                                                   M
# 1                                                   U
# 2                                                   M
# 3                                                   U
# 4                                                   U
# 5                                                   M
# 6                                                   U
# 7                                                   M
# 8                                                   M
# 9   C - Required if time synchronization was applied.
# 10                                                  M
# 11                                                  M
# 12                                                  M
# 13                                                  U
# 14       C - Required if contrast media were applied.
# 15                                                  M
# 16                                                  M
# 17  C - Required if cardiac synchronization was ap...
# 18  C - Required if respiratory synchronization wa...
# 19  C - Required if bulk motion synchronization wa...
# 20  C - Required if Pixel Presentation (0008,9205)...
# 21                                                  M
# 22                                                  U
# 23                                                  U
# 24                                                  M
# 25  C - Required if Image Type (0008,0008) Value 1...
# 26                                                  U
# 27                                                  M
# 28                                                  U
# 29  C - Required if the SOP Instance was created i...

# %%
set(df_iod.Usage)
# M : Mandatory
# U : User Optional
# C - Required if ~~ : Conditional
# Out:
# {'C - Required if Image Type (0008,0008) Value 1 is ORIGINAL or MIXED. May be present otherwise.',
#  'C - Required if Pixel Presentation (0008,9205) in the  equals COLOR or MIXED.',
#  'C - Required if bulk motion synchronization was applied.',
#  'C - Required if cardiac synchronization was applied.',
#  'C - Required if contrast media were applied.',
#  'C - Required if respiratory synchronization was applied.',
#  'C - Required if the SOP Instance was created in response to a Frame-Level retrieve request',
#  'C - Required if time synchronization was applied.',
#  'M',
#  'U'}

# %% [markdown]
# ## 1.b Extract Reference tables

# %%
import pandas as pd
from bs4 import BeautifulSoup

# Find the mapping table between reference module from IOD table to reference table
rows = []

df_reference = df_iod[df_iod['Usage']=="M"]

for section_id in df_reference['Reference']:
    section_element = soup.find('section', {'xml:id': section_id})
    
    if section_element:
        tables = section_element.findChildren('table', recursive=False)
        # For each table, create a dictionary with section_id and table XML id and add it to the rows list
        for table in tables:
            if table.has_attr('xml:id'):
                row = {'section_id': section_id, 'table_xml_id': table['xml:id']}
                rows.append(row)
# Create a DataFrame from the rows list
table_df = pd.DataFrame(rows)
table_df
# Out:
#        section_id      table_xml_id
# 0    sect_C.7.1.1       table_C.7-1
# 1    sect_C.7.2.1       table_C.7-3
# 2    sect_C.7.3.1      table_C.7-5a
# 3   sect_C.8.13.6     table_C.8-101
# 4    sect_C.7.4.1       table_C.7-6
# 5    sect_C.7.5.1       table_C.7-8
# 6    sect_C.7.5.2      table_C.7-8b
# 7    sect_C.7.6.3     table_C.7-11a
# 8   sect_C.7.6.16  table_C.7.6.16-1
# 9   sect_C.7.6.17  table_C.7.6.17-1
# 10  sect_C.7.6.14  table_C.7.6.14-1
# 11  sect_C.8.13.1      table_C.8-79
# 12    sect_C.12.1      table_C.12-1

# %%
def process_table(soup, table_xml_id):
    # Find the table using table_xml_id
    table = soup.find('table', {'xml:id': table_xml_id}) #첫번째 매개변수: 찾으려는 태그 이름 ex : 'table', 'section', 'div'
    section_xml_id = table.parent['xml:id']

    # Initialize lists to store extracted data
    attribute_names = []
    tags = []
    types = []
    attribute_descriptions = []
    cid = []

    # Extract data from the table rows
    for index, row in enumerate(table.find_all('tr')):
        columns = row.find_all('td')
        if len(columns) == 4:
            attribute_name = columns[0].text.strip()
            if attribute_name.startswith('>'):
                continue
            tag = columns[1].text.strip()
            type_ = columns[2].text.strip()
            description = columns[3].find_all('variablelist')

            defined_terms_dict = {}
            if description:
                for variablelist in description:
                    title = variablelist.title.text.strip().replace(':', '')
                    defined_terms = [term.text.strip() for term in variablelist.find_all('term')]
                    defined_terms_dict[title] = defined_terms
            
            attribute_names.append(attribute_name)
            tags.append(tag)
            types.append(type_)
            attribute_descriptions.append(defined_terms_dict)
            cid.append('')

        elif len(columns) == 2 and index != 0 and cid:
            first_col = columns[0].text.strip()
            if first_col.startswith('>>'):
                continue
            if first_col.startswith('>'):
                olink = columns[1].find('olink')
                if olink:
                    targetptr = olink.get('targetptr', '')
                    if 'CID_' in targetptr:
                        cid_value = targetptr.split('CID_')[-1]
                        cid[-1] += cid_value

    # Create a DataFrame from the extracted data
    data = {
        'section_id': section_xml_id,
        'Attribute Name': attribute_names,
        'Tag': tags,
        'Type': types,
        'Attribute Description': attribute_descriptions,
        'CID': cid
    }
    return pd.DataFrame(data)

# %%
reference_table_data = []
for table_xml_id in table_df['table_xml_id']:
    df = process_table(soup, table_xml_id)
    reference_table_data.append(df)

# combine all DataFrames into one
reference_tables = pd.concat(reference_table_data, ignore_index=True)
reference_tables

# Tag: data 고유 식별자 (groupnumber, elementnumber)
# Type: 데이터 요소 필수 여부와 유효성 type: 1(mandatory), 1C(conditional), 2(항상 존재해야하지만 비어있을 수 있음), 2C(2+ conditional), 3: Optinal
# CID: Context Identifier - value set definition
# Out:
#        section_id                                 Attribute Name          Tag  \
# 0    sect_C.7.1.1                                 Patient's Name  (0010,0010)
# 1    sect_C.7.1.1                                     Patient ID  (0010,0020)
# 2    sect_C.7.1.1                             Type of Patient ID  (0010,0022)
# 3    sect_C.7.1.1                           Patient's Birth Date  (0010,0030)
# 4    sect_C.7.1.1   Patient's Birth Date in Alternative Calendar  (0010,0033)
# ..            ...                                            ...          ...
# 166   sect_C.12.1          Conversion Source Attributes Sequence  (0020,9172)
# 167   sect_C.12.1                          Content Qualification  (0018,9004)
# 168   sect_C.12.1  Private Data Element Characteristics Sequence  (0008,0300)
# 169   sect_C.12.1                         Instance Origin Status  (0400,0600)
# 170   sect_C.12.1                                  Barcode Value  (2200,0005)
#
#     Type                              Attribute Description CID
# 0      2                                                 {}
# 1      2                                                 {}
# 2      3     {'Defined Terms': ['TEXT', 'RFID', 'BARCODE']}
# 3      2                                                 {}
# 4      3                                                 {}
# ..   ...                                                ...  ..
# 166   1C                                                 {}
# 167    3  {'Enumerated Values': ['PRODUCT', 'RESEARCH', ...
# 168    3                                                 {}
# 169    3                                                 {}
# 170    3                                                 {}
#
# [171 rows x 6 columns]

# %% [markdown]
# ## 2.a Extract Module Tables for all IODs

# %%
from bs4 import BeautifulSoup

# Fetch XML content from the URL
url = 'https://dicom.nema.org/medical/dicom/current/source/docbook/part03/part03.xml'
response = requests.get(url)
xml_content = response.content

# Parse the XML content
soup = BeautifulSoup(xml_content, 'xml')

# %%
import re
from bs4 import BeautifulSoup
import pandas as pd

data = []

for section_element in soup.find_all('section', {'label': re.compile('A.')}):
    # Find all table elements within the section_element
    tables = section_element.find_all('table')
    for table in tables:
        # Find the caption element for the current table
        caption = table.find('caption')
        # Check if the caption exists and matches the regular expression
        if caption and re.search('IOD Modules', caption.text):
            # Extract the xml:id attribute from the table
            table_id = table.get('xml:id')  # Use .get() to avoid KeyError if the attribute is missing
            # Append the xml:id and caption text to the data list
            data.append((table_id, caption.text.strip()))

# Create a DataFrame from the collected data
df_iod_tables = pd.DataFrame(data, columns=['xml_id', 'iod'])
df_iod_tables = df_iod_tables.drop_duplicates().reset_index(drop=True)

# %%
df_iod_tables
# Out:
#                xml_id                                                iod
# 0         table_A.2-1             Computed Radiography Image IOD Modules
# 1         table_A.3-1                               CT Image IOD Modules
# 2         table_A.4-1                               MR Image IOD Modules
# 3         table_A.5-1                 Nuclear Medicine Image IOD Modules
# 4         table_A.6-1                       Ultrasound Image IOD Modules
# ..                ...                                                ...
# 167    table_A.88.3-1                              Inventory IOD Modules
# 168    table_A.89.3-1                    Photoacoustic Image IOD Modules
# 169  table_A.90.1.3-1              Confocal Microscopy Image IOD Modules
# 170  table_A.90.2.3-1  Confocal Microscopy Tiled Pyramidal Image IOD ...
# 171      table_A.91-1                Height Map Segmentation IOD Modules
#
# [172 rows x 2 columns]

# %%
import pandas as pd

first_table_headers = None
table_data = []  # A list to store the DataFrame for each table

for index, row in df_iod_tables.iterrows():
    xml_id = row['xml_id']
    caption = row['iod']

    # Find the table in 'soup' with the matching 'xml:id'
    table = soup.find('table', {'xml:id': xml_id})
    if table:
        # Extract table headers
        headers = [th.text.strip() for th in table.find_all('th')]
        # If it's the first table, store its headers
        if first_table_headers is None:
            first_table_headers = headers
        # For subsequent tables, check if the headers match the first table's headers
        elif headers != first_table_headers:
            # If headers don't match, skip this table
            continue

        # Reset the current_ie for each table to ensure data integrity
        current_ie = None  
        rows = []
        
        for tr in table.find_all('tr')[1:]:  # Skip the header row
            cells = tr.find_all(['td', 'th'])
            # Extract cell values
            cell_values = [cell.text.strip() for cell in cells]

            # Check if the cell values are complete (some cells may be missing due to rowspan)
            if len(cell_values) < len(headers):
                # Fill in the missing values based on the previous row
                for i in range(len(headers) - len(cell_values)):
                    cell_values.insert(0, current_ie)

            # Update current_ie based on the first cell value (the IE column)
            current_ie = cell_values[0]

            # Extract the reference value if available
            reference = None
            for cell in cells:
                xref = cell.find('xref', {'xrefstyle': 'select: labelnumber'})
                if xref:
                    reference = xref['linkend']
                    break

            # Insert the reference value into the correct position
            if reference:
                # Find the index of the cell containing the reference
                reference_index = next((idx for idx, val in enumerate(cell_values) if val == ''), None)
                if reference_index is not None:
                    cell_values[reference_index] = reference

            # Append the row data
            table_data.append([xml_id, caption] + cell_values)

# Create the final DataFrame
final_df = pd.DataFrame(table_data, columns=['xml_id', 'iod'] + first_table_headers)

# %%
final_df['Usage_code'] = final_df['Usage'].str[0] # 문법 주의 : [0]으로 하면 ['Usage]의 가장 첫번째 값 반환! str[0]으로 해야 각 열의 code 반환
final_df
# Out:
#             xml_id                                     iod       IE  \
# 0      table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 1      table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 2      table_A.2-1  Computed Radiography Image IOD Modules    Study
# 3      table_A.2-1  Computed Radiography Image IOD Modules    Study
# 4      table_A.2-1  Computed Radiography Image IOD Modules    Study
# ...            ...                                     ...      ...
# 3302  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 3303  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 3304  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 3305  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 3306  table_A.91-1     Height Map Segmentation IOD Modules    Image
#
#                          Module     Reference  \
# 0                       Patient  sect_C.7.1.1
# 1        Clinical Trial Subject  sect_C.7.1.3
# 2                 General Study  sect_C.7.2.1
# 3                 Patient Study  sect_C.7.2.2
# 4          Clinical Trial Study  sect_C.7.2.3
# ...                         ...           ...
# 3302                ICC Profile  sect_C.11.15
# 3303                 SOP Common   sect_C.12.1
# 3304  Common Instance Reference   sect_C.12.2
# 3305           Frame Extraction   sect_C.12.3
# 3306          General Reference   sect_C.12.4
#
#                                                   Usage Usage_code
# 0                                                     M          M
# 1                                                     U          U
# 2                                                     M          M
# 3                                                     U          U
# 4                                                     U          U
# ...                                                 ...        ...
# 3302                                                  U          U
# 3303                                                  M          M
# 3304                                                  M          M
# 3305  C - Required if the SOP Instance was created i...          C
# 3306                                                  U          U
#
# [3307 rows x 7 columns]

# %%
final_df[final_df['xml_id']=="table_A.36-1"]
# Out:
#             xml_id                            iod                  IE  \
# 1614  table_A.36-1  Enhanced MR Image IOD Modules             Patient
# 1615  table_A.36-1  Enhanced MR Image IOD Modules             Patient
# 1616  table_A.36-1  Enhanced MR Image IOD Modules               Study
# 1617  table_A.36-1  Enhanced MR Image IOD Modules               Study
# 1618  table_A.36-1  Enhanced MR Image IOD Modules               Study
# 1619  table_A.36-1  Enhanced MR Image IOD Modules              Series
# 1620  table_A.36-1  Enhanced MR Image IOD Modules              Series
# 1621  table_A.36-1  Enhanced MR Image IOD Modules              Series
# 1622  table_A.36-1  Enhanced MR Image IOD Modules  Frame of Reference
# 1623  table_A.36-1  Enhanced MR Image IOD Modules  Frame of Reference
# 1624  table_A.36-1  Enhanced MR Image IOD Modules           Equipment
# 1625  table_A.36-1  Enhanced MR Image IOD Modules           Equipment
# 1626  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1627  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1628  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1629  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1630  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1631  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1632  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1633  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1634  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1635  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1636  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1637  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1638  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1639  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1640  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1641  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1642  table_A.36-1  Enhanced MR Image IOD Modules               Image
# 1643  table_A.36-1  Enhanced MR Image IOD Modules               Image
#
#                                        Module        Reference  \
# 1614                                  Patient     sect_C.7.1.1
# 1615                   Clinical Trial Subject     sect_C.7.1.3
# 1616                            General Study     sect_C.7.2.1
# 1617                            Patient Study     sect_C.7.2.2
# 1618                     Clinical Trial Study     sect_C.7.2.3
# 1619                           General Series     sect_C.7.3.1
# 1620                    Clinical Trial Series     sect_C.7.3.2
# 1621                                MR Series    sect_C.8.13.6
# 1622                       Frame of Reference     sect_C.7.4.1
# 1623                          Synchronization     sect_C.7.4.2
# 1624                        General Equipment     sect_C.7.5.1
# 1625               Enhanced General Equipment     sect_C.7.5.2
# 1626                              Image Pixel     sect_C.7.6.3
# 1627             Enhanced Patient Orientation    sect_C.7.6.30
# 1628                  Enhanced Contrast/Bolus    sect_C.7.6.4b
# 1629            Multi-frame Functional Groups    sect_C.7.6.16
# 1630                    Multi-frame Dimension    sect_C.7.6.17
# 1631                  Cardiac Synchronization  sect_C.7.6.18.1
# 1632              Respiratory Synchronization  sect_C.7.6.18.2
# 1633              Bulk Motion Synchronization  sect_C.7.6.18.3
# 1634  Supplemental Palette Color Lookup Table    sect_C.7.6.19
# 1635                      Acquisition Context    sect_C.7.6.14
# 1636                                   Device    sect_C.7.6.12
# 1637                                 Specimen    sect_C.7.6.22
# 1638                        Enhanced MR Image    sect_C.8.13.1
# 1639                        MR Pulse Sequence    sect_C.8.13.4
# 1640                              ICC Profile     sect_C.11.15
# 1641                               SOP Common      sect_C.12.1
# 1642                Common Instance Reference      sect_C.12.2
# 1643                         Frame Extraction      sect_C.12.3
#
#                                                   Usage Usage_code
# 1614                                                  M          M
# 1615                                                  U          U
# 1616                                                  M          M
# 1617                                                  U          U
# 1618                                                  U          U
# 1619                                                  M          M
# 1620                                                  U          U
# 1621                                                  M          M
# 1622                                                  M          M
# 1623  C - Required if time synchronization was applied.          C
# 1624                                                  M          M
# 1625                                                  M          M
# 1626                                                  M          M
# 1627                                                  U          U
# 1628       C - Required if contrast media were applied.          C
# 1629                                                  M          M
# 1630                                                  M          M
# 1631  C - Required if cardiac synchronization was ap...          C
# 1632  C - Required if respiratory synchronization wa...          C
# 1633  C - Required if bulk motion synchronization wa...          C
# 1634  C - Required if Pixel Presentation (0008,9205)...          C
# 1635                                                  M          M
# 1636                                                  U          U
# 1637                                                  U          U
# 1638                                                  M          M
# 1639  C - Required if Image Type (0008,0008) Value 1...          C
# 1640                                                  U          U
# 1641                                                  M          M
# 1642                                                  U          U
# 1643  C - Required if the SOP Instance was created i...          C

# %%
final_df.groupby('Usage_code')['xml_id'].count() #groupby(condition column)[pk]
# Out:
# Usage_code
# C     319
# M    1782
# U    1206
# Name: xml_id, dtype: int64

# %%
final_df['iod'].nunique()
# Out:
# 172

# %%
final_df['xml_id'].nunique()
# Out:
# 172

# %%
final_df['Reference'].nunique()
# Out:
# 360

# %% [markdown]
# ### Exception handling
# It looks like we have a list of Reference tables that needed further adjustments. Upon investigation, I found that the standard for Reference tables above redirect to another table or tables. To handle this exception, I have manually collected the redirected References and created a dataframe as mapping_data.

# %%
#'sect_C.8.15.4': 'sect_C.8.2.2.1', 'sect_C.8.2.2.2', 'sect_C.8.2.2.3'
#'sect_C.11.11': 'sect_C.11.11.1'
#'sect_C.17.3': 'sect_C.17.3.3', 'sect_C.17.3.4'
#'sect_C.7.6.20': 'sect_C.10.12'
#'sect_C.28.1':'sect_C.10.9'
#'sect_C.29.3':'sect_C.29.3.1'
#'sect_C.36.18': 'sect_C.36.2.2.7', 'sect_C.36.2.2.8', 'sect_C.36.2.2.14'

mapping_data = {
    'Reference': ['sect_C.8.15.4', 'sect_C.8.15.4', 'sect_C.8.15.4', 'sect_C.11.11', 'sect_C.17.3', 'sect_C.17.3', 'sect_C.7.6.20', 'sect_C.28.1', 'sect_C.29.3', 'sect_C.36.18', 'sect_C.36.18', 'sect_C.36.18'],
    'Reference_adjusted': ['sect_C.8.2.2.1', 'sect_C.8.2.2.2', 'sect_C.8.2.2.3', 'sect_C.11.11.1', 'sect_C.17.3.3', 'sect_C.17.3.4', 'sect_C.10.12', 'sect_C.10.9', 'sect_C.29.3.1', 'sect_C.36.2.2.7', 'sect_C.36.2.2.8', 'sect_C.36.2.2.14']
}
mapping_data = pd.DataFrame(mapping_data)
mapping_data
# Out:
#         Reference Reference_adjusted
# 0   sect_C.8.15.4     sect_C.8.2.2.1
# 1   sect_C.8.15.4     sect_C.8.2.2.2
# 2   sect_C.8.15.4     sect_C.8.2.2.3
# 3    sect_C.11.11     sect_C.11.11.1
# 4     sect_C.17.3      sect_C.17.3.3
# 5     sect_C.17.3      sect_C.17.3.4
# 6   sect_C.7.6.20       sect_C.10.12
# 7     sect_C.28.1        sect_C.10.9
# 8     sect_C.29.3      sect_C.29.3.1
# 9    sect_C.36.18    sect_C.36.2.2.7
# 10   sect_C.36.18    sect_C.36.2.2.8
# 11   sect_C.36.18   sect_C.36.2.2.14

# %%
final_df_expanded = pd.merge(final_df, mapping_data, on = 'Reference', how = 'left')
final_df_expanded['Reference_adjusted'] = final_df_expanded['Reference_adjusted'].fillna(final_df_expanded['Reference']) #Reference_adjusted에 해당되징 않는 값들은 원래대로 반환환
final_df_expanded
# Out:
#             xml_id                                     iod       IE  \
# 0      table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 1      table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 2      table_A.2-1  Computed Radiography Image IOD Modules    Study
# 3      table_A.2-1  Computed Radiography Image IOD Modules    Study
# 4      table_A.2-1  Computed Radiography Image IOD Modules    Study
# ...            ...                                     ...      ...
# 3331  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 3332  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 3333  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 3334  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 3335  table_A.91-1     Height Map Segmentation IOD Modules    Image
#
#                          Module     Reference  \
# 0                       Patient  sect_C.7.1.1
# 1        Clinical Trial Subject  sect_C.7.1.3
# 2                 General Study  sect_C.7.2.1
# 3                 Patient Study  sect_C.7.2.2
# 4          Clinical Trial Study  sect_C.7.2.3
# ...                         ...           ...
# 3331                ICC Profile  sect_C.11.15
# 3332                 SOP Common   sect_C.12.1
# 3333  Common Instance Reference   sect_C.12.2
# 3334           Frame Extraction   sect_C.12.3
# 3335          General Reference   sect_C.12.4
#
#                                                   Usage Usage_code  \
# 0                                                     M          M
# 1                                                     U          U
# 2                                                     M          M
# 3                                                     U          U
# 4                                                     U          U
# ...                                                 ...        ...
# 3331                                                  U          U
# 3332                                                  M          M
# 3333                                                  M          M
# 3334  C - Required if the SOP Instance was created i...          C
# 3335                                                  U          U
#
#      Reference_adjusted
# 0          sect_C.7.1.1
# 1          sect_C.7.1.3
# 2          sect_C.7.2.1
# 3          sect_C.7.2.2
# 4          sect_C.7.2.3
# ...                 ...
# 3331       sect_C.11.15
# 3332        sect_C.12.1
# 3333        sect_C.12.2
# 3334        sect_C.12.3
# 3335        sect_C.12.4
#
# [3336 rows x 8 columns]

# %%
final_df_expanded[final_df_expanded['Reference']!= final_df_expanded['Reference_adjusted']]
# Out:
#                  xml_id                                                iod  \
# 896      table_A.33.1-1  Grayscale Softcopy Presentation State IOD Modules
# 924      table_A.33.2-1      Color Softcopy Presentation State IOD Modules
# 948      table_A.33.3-1  Pseudo-Color Softcopy Presentation State IOD M...
# 1014     table_A.33.6-1  XA/XRF Grayscale Softcopy Presentation State I...
# 1063     table_A.33.8-1  Variable Modality LUT Softcopy Presentation St...
# ...                 ...                                                ...
# 3014   table_A.86.1.7-1                  Robotic-Arm Radiation IOD Modules
# 3015   table_A.86.1.7-1                  Robotic-Arm Radiation IOD Modules
# 3109  table_A.86.1.12-1           Robotic-Arm Radiation Record IOD Modules
# 3110  table_A.86.1.12-1           Robotic-Arm Radiation Record IOD Modules
# 3111  table_A.86.1.12-1           Robotic-Arm Radiation Record IOD Modules
#
#                           IE                           Module     Reference  \
# 896       Presentation State  Presentation State Relationship  sect_C.11.11
# 924       Presentation State  Presentation State Relationship  sect_C.11.11
# 948       Presentation State  Presentation State Relationship  sect_C.11.11
# 1014      Presentation State  Presentation State Relationship  sect_C.11.11
# 1063      Presentation State  Presentation State Relationship  sect_C.11.11
# ...                      ...                              ...           ...
# 3014            RT Radiation      Robotic-Arm Delivery Device  sect_C.36.18
# 3015            RT Radiation      Robotic-Arm Delivery Device  sect_C.36.18
# 3109  RT Delivered Radiation      Robotic-Arm Delivery Device  sect_C.36.18
# 3110  RT Delivered Radiation      Robotic-Arm Delivery Device  sect_C.36.18
# 3111  RT Delivered Radiation      Robotic-Arm Delivery Device  sect_C.36.18
#
#      Usage Usage_code Reference_adjusted
# 896      M          M     sect_C.11.11.1
# 924      M          M     sect_C.11.11.1
# 948      M          M     sect_C.11.11.1
# 1014     M          M     sect_C.11.11.1
# 1063     M          M     sect_C.11.11.1
# ...    ...        ...                ...
# 3014     M          M    sect_C.36.2.2.8
# 3015     M          M   sect_C.36.2.2.14
# 3109     M          M    sect_C.36.2.2.7
# 3110     M          M    sect_C.36.2.2.8
# 3111     M          M   sect_C.36.2.2.14
#
# [65 rows x 8 columns]

# %%
final_df_expanded['Reference_adjusted'].nunique()
# Out:
# 364

# %% [markdown]
# ## 2.b Extract all Reference tables

# %%
# Find the mapping table between reference module from IOD table to reference table
# Find from the all IOD list for ALL usage
rows = []

df_reference = final_df_expanded['Reference_adjusted'].drop_duplicates()

for section_id in df_reference:
    section_element = soup.find('section', {'xml:id': section_id})
    
    if section_element:
        tables = section_element.findChildren('table', recursive=False)
        # For each table, create a dictionary with section_id and table XML id and add it to the rows list
        for table in tables:
            if table.has_attr('xml:id'):
                row = {'section_id': section_id, 'table_xml_id': table['xml:id']}
                rows.append(row)
# Create a DataFrame from the rows list
table_df = pd.DataFrame(rows)
table_df
# Out:
#         section_id      table_xml_id
# 0     sect_C.7.1.1       table_C.7-1
# 1     sect_C.7.1.3      table_C.7-2b
# 2     sect_C.7.2.1       table_C.7-3
# 3     sect_C.7.2.2      table_C.7-4a
# 4     sect_C.7.2.3      table_C.7-4b
# ..             ...               ...
# 371  sect_C.8.34.3  table_C.8.34.3-1
# 372  sect_C.8.34.4  table_C.8.34.4-1
# 373  sect_C.8.35.1  table_C.8.35.1-1
# 374  sect_C.8.35.3  table_C.8.35.3-1
# 375  sect_C.8.35.2  table_C.8.35.2-1
#
# [376 rows x 2 columns]

# %%
table_df_agg = table_df.groupby('section_id')['table_xml_id'].agg(count = 'count').reset_index()
multiple_ref_tables = table_df_agg[table_df_agg['count']>1]['section_id']

# %%
dedup_table_xml = table_df[table_df['section_id'].isin(multiple_ref_tables)]
dedup_table_xml = dedup_table_xml.groupby('section_id').nth(1).reset_index(drop=True)
dedup_table_xml
# Out:
# Empty DataFrame
# Columns: [section_id, table_xml_id]
# Index: []

# %%
table_df_new = table_df.merge(dedup_table_xml, on = 'section_id', how = 'left', suffixes=('', '_adj'))
table_df_new['table_xml_id_new'] = table_df_new['table_xml_id_adj'].combine_first(table_df_new['table_xml_id'])
table_df_new
# Out:
#        section_id      table_xml_id table_xml_id_adj  table_xml_id_new
# 0    sect_C.7.1.1       table_C.7-1              NaN       table_C.7-1
# 1    sect_C.7.2.1       table_C.7-3              NaN       table_C.7-3
# 2    sect_C.7.3.1      table_C.7-5a              NaN      table_C.7-5a
# 3   sect_C.8.13.6     table_C.8-101              NaN     table_C.8-101
# 4    sect_C.7.4.1       table_C.7-6              NaN       table_C.7-6
# 5    sect_C.7.5.1       table_C.7-8              NaN       table_C.7-8
# 6    sect_C.7.5.2      table_C.7-8b              NaN      table_C.7-8b
# 7    sect_C.7.6.3     table_C.7-11a              NaN     table_C.7-11a
# 8   sect_C.7.6.16  table_C.7.6.16-1              NaN  table_C.7.6.16-1
# 9   sect_C.7.6.17  table_C.7.6.17-1              NaN  table_C.7.6.17-1
# 10  sect_C.7.6.14  table_C.7.6.14-1              NaN  table_C.7.6.14-1
# 11  sect_C.8.13.1      table_C.8-79              NaN      table_C.8-79
# 12    sect_C.12.1      table_C.12-1              NaN      table_C.12-1

# %%
table_df_new = table_df_new[['section_id', 'table_xml_id_new']].drop_duplicates().reset_index(drop=True)

# %%
# same function as above 
import pandas as pd
from bs4 import BeautifulSoup

def process_table(soup, table_xml_id):
    # Find the table using table_xml_id
    table = soup.find('table', {'xml:id': table_xml_id})
    section_xml_id = table.parent['xml:id']

    # Initialize lists to store extracted data
    attribute_names = []
    tags = []
    types = []
    attribute_descriptions = []
    cid = []

    # Extract data from the table rows
    for index, row in enumerate(table.find_all('tr')):
        columns = row.find_all('td')
        if len(columns) == 4:
            attribute_name = columns[0].text.strip()
            if attribute_name.startswith('>'):
                continue
            tag = columns[1].text.strip()
            type_ = columns[2].text.strip()
            description = columns[3].find_all('variablelist')

            defined_terms_dict = {}
            if description:
                for variablelist in description:
                    title = variablelist.title.text.strip().replace(':', '')
                    defined_terms = [term.text.strip() for term in variablelist.find_all('term')]
                    defined_terms_dict[title] = defined_terms
            
            attribute_names.append(attribute_name)
            tags.append(tag)
            types.append(type_)
            attribute_descriptions.append(defined_terms_dict)
            cid.append('')

        elif len(columns) == 2 and index != 0 and cid:
            first_col = columns[0].text.strip()
            if first_col.startswith('>>'):
                continue
            if first_col.startswith('>'):
                olink = columns[1].find('olink')
                if olink:
                    targetptr = olink.get('targetptr', '')
                    if 'CID_' in targetptr:
                        cid_value = targetptr.split('CID_')[-1]
                        cid[-1] += cid_value

    # Create a DataFrame from the extracted data
    data = {
        'section_id': section_xml_id,
        'Attribute Name': attribute_names,
        'Tag': tags,
        'Type': types,
        'Attribute Description': attribute_descriptions,
        'CID': cid
    }
    return pd.DataFrame(data)

# %%
reference_table_data = []
for table_xml_id in table_df_new['table_xml_id_new']:
    df = process_table(soup, table_xml_id)
    reference_table_data.append(df)

# combine all DataFrames into one
reference_tables = pd.concat(reference_table_data, ignore_index=True)

# %%
# subset of tags based on type = required
reference_tables[reference_tables['Type']=='1']
# Out:
#         section_id                     Attribute Name          Tag Type  \
# 34    sect_C.7.2.1                 Study Instance UID  (0020,000D)    1
# 54    sect_C.7.3.1                           Modality  (0008,0060)    1
# 55    sect_C.7.3.1                Series Instance UID  (0020,000E)    1
# 76   sect_C.8.13.6                           Modality  (0008,0060)    1
# 78    sect_C.7.4.1             Frame of Reference UID  (0020,0052)    1
# 99    sect_C.7.5.2                       Manufacturer  (0008,0070)    1
# 100   sect_C.7.5.2          Manufacturer's Model Name  (0008,1090)    1
# 101   sect_C.7.5.2               Device Serial Number  (0018,1000)    1
# 102   sect_C.7.5.2                  Software Versions  (0018,1020)    1
# 108  sect_C.7.6.16  Shared Functional Groups Sequence  (5200,9229)    1
# 110  sect_C.7.6.16                    Instance Number  (0020,0013)    1
# 111  sect_C.7.6.16                       Content Date  (0008,0023)    1
# 112  sect_C.7.6.16                       Content Time  (0008,0033)    1
# 113  sect_C.7.6.16                   Number of Frames  (0028,0008)    1
# 122  sect_C.7.6.17    Dimension Organization Sequence  (0020,9221)    1
# 127  sect_C.8.13.1                         Image Type  (0008,0008)    1
# 128  sect_C.8.13.1                  Samples per Pixel  (0028,0002)    1
# 129  sect_C.8.13.1         Photometric Interpretation  (0028,0004)    1
# 130  sect_C.8.13.1                     Bits Allocated  (0028,0100)    1
# 131  sect_C.8.13.1                        Bits Stored  (0028,0101)    1
# 132  sect_C.8.13.1                           High Bit  (0028,0102)    1
# 133  sect_C.8.13.1               Pixel Representation  (0028,0103)    1
# 142    sect_C.12.1                      SOP Class UID  (0008,0016)    1
# 143    sect_C.12.1                   SOP Instance UID  (0008,0018)    1
#
#              Attribute Description CID
# 34                              {}
# 54                              {}
# 55                              {}
# 76   {'Enumerated Values': ['MR']}
# 78                              {}
# 99                              {}
# 100                             {}
# 101                             {}
# 102                             {}
# 108                             {}
# 110                             {}
# 111                             {}
# 112                             {}
# 113                             {}
# 122                             {}
# 127                             {}
# 128                             {}
# 129                             {}
# 130                             {}
# 131                             {}
# 132                             {}
# 133                             {}
# 142                             {}
# 143                             {}

# %%
# subset of tags with attribute description
reference_tables[reference_tables['Attribute Description']!= {}]
# Out:
#         section_id                              Attribute Name          Tag  \
# 2     sect_C.7.1.1                          Type of Patient ID  (0010,0022)
# 7     sect_C.7.1.1                               Patient's Sex  (0010,0040)
# 9     sect_C.7.1.1                     Quality Control Subject  (0010,0200)
# 31    sect_C.7.1.1                    Patient Identity Removed  (0012,0062)
# 57    sect_C.7.3.1                                  Laterality  (0020,0060)
# 74    sect_C.7.3.1                 Anatomical Orientation Type  (0010,2210)
# 76   sect_C.8.13.6                                    Modality  (0008,0060)
# 114  sect_C.7.6.16                        Stereo Pairs Present  (0022,0028)
# 123  sect_C.7.6.17                 Dimension Organization Type  (0020,9311)
# 135  sect_C.8.13.1                        Burned In Annotation  (0028,0301)
# 136  sect_C.8.13.1                Recognizable Visual Features  (0028,0302)
# 137  sect_C.8.13.1                     Lossy Image Compression  (0028,2110)
# 140  sect_C.8.13.1                      Presentation LUT Shape  (2050,0020)
# 151    sect_C.12.1                              Synthetic Data  (0008,001C)
# 158    sect_C.12.1                         SOP Instance Status  (0100,0410)
# 164    sect_C.12.1  Longitudinal Temporal Information Modified  (0028,0303)
# 165    sect_C.12.1                         Query/Retrieve View  (0008,0053)
# 167    sect_C.12.1                       Content Qualification  (0018,9004)
#
#     Type                              Attribute Description CID
# 2      3     {'Defined Terms': ['TEXT', 'RFID', 'BARCODE']}
# 7      2             {'Enumerated Values': ['M', 'F', 'O']}
# 9      3               {'Enumerated Values': ['YES', 'NO']}
# 31     3               {'Enumerated Values': ['YES', 'NO']}
# 57    2C                  {'Enumerated Values': ['R', 'L']}
# 74    1C      {'Enumerated Values': ['BIPED', 'QUADRUPED']}
# 76     1                      {'Enumerated Values': ['MR']}
# 114    3               {'Enumerated Values': ['YES', 'NO']}
# 123    3  {'Defined Terms': ['3D', '3D_TEMPORAL', 'TILED...
# 135   1C                      {'Enumerated Values': ['NO']}
# 136    3               {'Enumerated Values': ['YES', 'NO']}
# 137   1C                {'Enumerated Values': ['00', '01']}
# 140   1C                {'Enumerated Values': ['IDENTITY']}
# 151    3               {'Enumerated Values': ['YES', 'NO']}
# 158    3    {'Enumerated Values': ['NS', 'OR', 'AO', 'AC']}
# 164    3  {'Enumerated Values': ['UNMODIFIED', 'MODIFIED...
# 165   1C     {'Enumerated Values': ['CLASSIC', 'ENHANCED']}
# 167    3  {'Enumerated Values': ['PRODUCT', 'RESEARCH', ...

# %%
# subset of tags with CIDs
reference_tables[reference_tables['CID']!='']
# Out:
#       section_id                               Attribute Name          Tag  \
# 15  sect_C.7.1.1                   Ethnic Group Code Sequence  (0010,2161)
# 18  sect_C.7.1.1                Patient Species Code Sequence  (0010,2202)
# 20  sect_C.7.1.1                  Patient Breed Code Sequence  (0010,2293)
# 33  sect_C.7.1.1       De-identification Method Code Sequence  (0012,0064)
# 50  sect_C.7.2.1             Requesting Service Code Sequence  (0032,1034)
# 52  sect_C.7.2.1                      Procedure Code Sequence  (0008,1032)
# 85  sect_C.7.5.1  Institutional Department Type Code Sequence  (0008,1041)
#
#    Type Attribute Description   CID
# 15    3                    {}  6099
# 18   1C                    {}  7454
# 20   2C                    {}  7480
# 33   1C                    {}  7050
# 50    3                    {}  7030
# 52    3                    {}   101
# 85    3                    {}  7030

# %%
# create one dataframe and export the file
mapping_table = pd.merge(final_df_expanded, reference_tables, left_on = 'Reference_adjusted', right_on = 'section_id', how = 'left')
mapping_table
# Out:
#              xml_id                                     iod       IE  \
# 0       table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 1       table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 2       table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 3       table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 4       table_A.2-1  Computed Radiography Image IOD Modules  Patient
# ...             ...                                     ...      ...
# 23440  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 23441  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 23442  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 23443  table_A.91-1     Height Map Segmentation IOD Modules    Image
# 23444  table_A.91-1     Height Map Segmentation IOD Modules    Image
#
#                           Module     Reference  \
# 0                        Patient  sect_C.7.1.1
# 1                        Patient  sect_C.7.1.1
# 2                        Patient  sect_C.7.1.1
# 3                        Patient  sect_C.7.1.1
# 4                        Patient  sect_C.7.1.1
# ...                          ...           ...
# 23440                 SOP Common   sect_C.12.1
# 23441                 SOP Common   sect_C.12.1
# 23442  Common Instance Reference   sect_C.12.2
# 23443           Frame Extraction   sect_C.12.3
# 23444          General Reference   sect_C.12.4
#
#                                                    Usage Usage_code  \
# 0                                                      M          M
# 1                                                      M          M
# 2                                                      M          M
# 3                                                      M          M
# 4                                                      M          M
# ...                                                  ...        ...
# 23440                                                  M          M
# 23441                                                  M          M
# 23442                                                  M          M
# 23443  C - Required if the SOP Instance was created i...          C
# 23444                                                  U          U
#
#       Reference_adjusted    section_id  \
# 0           sect_C.7.1.1  sect_C.7.1.1
# 1           sect_C.7.1.1  sect_C.7.1.1
# 2           sect_C.7.1.1  sect_C.7.1.1
# 3           sect_C.7.1.1  sect_C.7.1.1
# 4           sect_C.7.1.1  sect_C.7.1.1
# ...                  ...           ...
# 23440        sect_C.12.1   sect_C.12.1
# 23441        sect_C.12.1   sect_C.12.1
# 23442        sect_C.12.2           NaN
# 23443        sect_C.12.3           NaN
# 23444        sect_C.12.4           NaN
#
#                                      Attribute Name          Tag Type  \
# 0                                    Patient's Name  (0010,0010)    2
# 1                                        Patient ID  (0010,0020)    2
# 2                                Type of Patient ID  (0010,0022)    3
# 3                              Patient's Birth Date  (0010,0030)    2
# 4      Patient's Birth Date in Alternative Calendar  (0010,0033)    3
# ...                                             ...          ...  ...
# 23440                        Instance Origin Status  (0400,0600)    3
# 23441                                 Barcode Value  (2200,0005)    3
# 23442                                           NaN          NaN  NaN
# 23443                                           NaN          NaN  NaN
# 23444                                           NaN          NaN  NaN
#
#                                 Attribute Description  CID
# 0                                                  {}
# 1                                                  {}
# 2      {'Defined Terms': ['TEXT', 'RFID', 'BARCODE']}
# 3                                                  {}
# 4                                                  {}
# ...                                               ...  ...
# 23440                                              {}
# 23441                                              {}
# 23442                                             NaN  NaN
# 23443                                             NaN  NaN
# 23444                                             NaN  NaN
#
# [23445 rows x 14 columns]

# %%
mapping_table['Tag'] = mapping_table['Tag'].str.replace(r'[(),]', '', regex = True)
mapping_table = mapping_table.drop(columns=['section_id'])
mapping_table.head()
# Out:
#         xml_id                                     iod       IE   Module  \
# 0  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 1  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 2  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 3  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 4  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
#
#       Reference Usage Usage_code Reference_adjusted  \
# 0  sect_C.7.1.1     M          M       sect_C.7.1.1
# 1  sect_C.7.1.1     M          M       sect_C.7.1.1
# 2  sect_C.7.1.1     M          M       sect_C.7.1.1
# 3  sect_C.7.1.1     M          M       sect_C.7.1.1
# 4  sect_C.7.1.1     M          M       sect_C.7.1.1
#
#                                  Attribute Name       Tag Type  \
# 0                                Patient's Name  00100010    2
# 1                                    Patient ID  00100020    2
# 2                            Type of Patient ID  00100022    3
# 3                          Patient's Birth Date  00100030    2
# 4  Patient's Birth Date in Alternative Calendar  00100033    3
#
#                             Attribute Description CID
# 0                                              {}
# 1                                              {}
# 2  {'Defined Terms': ['TEXT', 'RFID', 'BARCODE']}
# 3                                              {}
# 4                                              {}

# %% [markdown]
# ## Add SOP Class UID from Part 4
# *Extract Part 4 ("DICOM_P4_harvest_SOP) before running*

# %%
mapping_table['short_iod'] = mapping_table['iod'].str.replace(' IOD Modules', '')

# %%
sop = pd.read_csv("../files/DICOM Standard/part4_sop_class.csv")
sop['Truncated SOP Class Name'] = sop['Truncated SOP Class Name'].str.replace(' Storage', '')

# %%
update_dict = {"Cardiac Electrophysiology Waveform Storage": "Basic Cardiac EP",
 "Ambulatory ECG Waveform Storage": "Ambulatory ECG",
 "General ECG Waveform Storage": "General ECG",
 "12-lead ECG Waveform Storage": "12-Lead ECG"
}

def update_truncated_sop_class_name(row):
    if row['SOP Class Name'] in update_dict:
        return update_dict[row['SOP Class Name']]
    return row['Truncated SOP Class Name']

# Apply the function to update the column
sop['Truncated SOP Class Name'] = sop.apply(update_truncated_sop_class_name, axis=1)

# %%
sop[sop['SOP Class Name'].isin(update_dict.keys())]
# Out:
#                                 SOP Class Name                  SOP Class UID  \
# 24                12-lead ECG Waveform Storage  1.2.840.10008.5.1.4.1.1.9.1.1
# 25                General ECG Waveform Storage  1.2.840.10008.5.1.4.1.1.9.1.2
# 26             Ambulatory ECG Waveform Storage  1.2.840.10008.5.1.4.1.1.9.1.3
# 29  Cardiac Electrophysiology Waveform Storage  1.2.840.10008.5.1.4.1.1.9.3.1
#
#    Truncated SOP Class Name
# 24              12-Lead ECG
# 25              General ECG
# 26           Ambulatory ECG
# 29         Basic Cardiac EP

# %%
# Truncated SOP Class Name, SOP Class UID
data = {
    "SOP Class Name": [
        "Implantation Plan SR Document Storage",
        "RT Treatment Summary Record Storage",
        "RT Ion Plan Storage",
        "RT Ion Beams Treatment Record Storage",
        "RT Beams Delivery Instruction Storage",
        "Generic Implant Template Storage",
        "Implant Assembly Template Storage",
        "Implant Template Group Storage"
        ],
    "SOP Class UID": [
        "1.2.840.10008.5.1.4.1.1.88.70",
        "1.2.840.10008.5.1.4.1.1.481.7",
        "1.2.840.10008.5.1.4.1.1.481.8",
        "1.2.840.10008.5.1.4.1.1.481.9",
        "1.2.840.10008.5.1.4.34.7",
        "1.2.840.10008.5.1.4.43.1",
        "1.2.840.10008.5.1.4.44.1",
        "1.2.840.10008.5.1.4.45.1"
        ],
    "Truncated SOP Class Name": [
        "Implantation Plan SR Document",
        "RT Treatment Summary Record",
        "RT Ion Plan",
        "RT Ion Beams Treatment Record",
        "RT Beams Delivery Instruction",
        "Generic Implant Template",
        "Implant Assembly Template",
        "Implant Template Group"
        ]
}

data_input = pd.DataFrame(data)

# Concatenate the original DataFrame with the new rows DataFrame
sop = pd.concat([sop, data_input], ignore_index=True)

# %%
mapping_table = mapping_table.merge(sop, left_on = 'short_iod', right_on = 'Truncated SOP Class Name', how = 'left')
mapping_table.head()
# Out:
#         xml_id                                     iod       IE   Module  \
# 0  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 1  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 2  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 3  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 4  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
#
#       Reference Usage Usage_code Reference_adjusted  \
# 0  sect_C.7.1.1     M          M       sect_C.7.1.1
# 1  sect_C.7.1.1     M          M       sect_C.7.1.1
# 2  sect_C.7.1.1     M          M       sect_C.7.1.1
# 3  sect_C.7.1.1     M          M       sect_C.7.1.1
# 4  sect_C.7.1.1     M          M       sect_C.7.1.1
#
#                                  Attribute Name       Tag Type  \
# 0                                Patient's Name  00100010    2
# 1                                    Patient ID  00100020    2
# 2                            Type of Patient ID  00100022    3
# 3                          Patient's Birth Date  00100030    2
# 4  Patient's Birth Date in Alternative Calendar  00100033    3
#
#                             Attribute Description CID  \
# 0                                              {}
# 1                                              {}
# 2  {'Defined Terms': ['TEXT', 'RFID', 'BARCODE']}
# 3                                              {}
# 4                                              {}
#
#              SOP Class UID_x                   short_iod  \
# 0  1.2.840.10008.5.1.4.1.1.1  Computed Radiography Image
# 1  1.2.840.10008.5.1.4.1.1.1  Computed Radiography Image
# 2  1.2.840.10008.5.1.4.1.1.1  Computed Radiography Image
# 3  1.2.840.10008.5.1.4.1.1.1  Computed Radiography Image
# 4  1.2.840.10008.5.1.4.1.1.1  Computed Radiography Image
#
#                        SOP Class Name            SOP Class UID_y  \
# 0  Computed Radiography Image Storage  1.2.840.10008.5.1.4.1.1.1
# 1  Computed Radiography Image Storage  1.2.840.10008.5.1.4.1.1.1
# 2  Computed Radiography Image Storage  1.2.840.10008.5.1.4.1.1.1
# 3  Computed Radiography Image Storage  1.2.840.10008.5.1.4.1.1.1
# 4  Computed Radiography Image Storage  1.2.840.10008.5.1.4.1.1.1
#
#      Truncated SOP Class Name
# 0  Computed Radiography Image
# 1  Computed Radiography Image
# 2  Computed Radiography Image
# 3  Computed Radiography Image
# 4  Computed Radiography Image

# %%
mapping_table = mapping_table.drop(columns = ['short_iod', 'Truncated SOP Class Name', 'SOP Class Name'])
mapping_table.head()
# Out:
#         xml_id                                     iod       IE   Module  \
# 0  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 1  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 2  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 3  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
# 4  table_A.2-1  Computed Radiography Image IOD Modules  Patient  Patient
#
#       Reference Usage Usage_code Reference_adjusted  \
# 0  sect_C.7.1.1     M          M       sect_C.7.1.1
# 1  sect_C.7.1.1     M          M       sect_C.7.1.1
# 2  sect_C.7.1.1     M          M       sect_C.7.1.1
# 3  sect_C.7.1.1     M          M       sect_C.7.1.1
# 4  sect_C.7.1.1     M          M       sect_C.7.1.1
#
#                                  Attribute Name       Tag Type  \
# 0                                Patient's Name  00100010    2
# 1                                    Patient ID  00100020    2
# 2                            Type of Patient ID  00100022    3
# 3                          Patient's Birth Date  00100030    2
# 4  Patient's Birth Date in Alternative Calendar  00100033    3
#
#                             Attribute Description CID  \
# 0                                              {}
# 1                                              {}
# 2  {'Defined Terms': ['TEXT', 'RFID', 'BARCODE']}
# 3                                              {}
# 4                                              {}
#
#              SOP Class UID_x            SOP Class UID_y
# 0  1.2.840.10008.5.1.4.1.1.1  1.2.840.10008.5.1.4.1.1.1
# 1  1.2.840.10008.5.1.4.1.1.1  1.2.840.10008.5.1.4.1.1.1
# 2  1.2.840.10008.5.1.4.1.1.1  1.2.840.10008.5.1.4.1.1.1
# 3  1.2.840.10008.5.1.4.1.1.1  1.2.840.10008.5.1.4.1.1.1
# 4  1.2.840.10008.5.1.4.1.1.1  1.2.840.10008.5.1.4.1.1.1

# %%
mapping_table.to_pickle('../files/DICOM Standard/part3_mapping.pkl')
